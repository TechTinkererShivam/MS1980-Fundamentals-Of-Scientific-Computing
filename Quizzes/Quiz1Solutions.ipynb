# %% [markdown]
# ![Screenshot 2024-10-08 164831.png](<attachment:Screenshot 2024-10-08 164831.png>)

# %%
def list_contains_empty_tuple(mylist_of_tuples):
    for t in mylist_of_tuples:
        if not t:
            return True
    return False

# Test function
my_list1 = [(), (1,2,3),('a',2), ('Hello',),(1.2,0.2,3),()]
print(list_contains_empty_tuple(my_list1)) # Returns True
# Out:
# True

# %% [markdown]
# ![Screenshot 2024-10-08 164843.png](<attachment:Screenshot 2024-10-08 164843.png>)

# %%
a = 10
print(x)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 2
#       1 a = 10
# ----> 2 print(x)
#
# NameError: name 'x' is not defined

# %%
my_list1 = [(), (1,2,3),('a',2), ('Hello',),(1.2,0.2,3),()]
print(my_list1[len(my_list1)])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[4], line 2
#       1 my_list1 = [(), (1,2,3),('a',2), ('Hello',),(1.2,0.2,3),()]
# ----> 2 print(my_list1[len(my_list1)])
#
# IndexError: list index out of range

# %%
my_dict = {
    'A' : 90,
    'B' : 80,
    'C' : 70
}
print(my_dict['D'])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[9], line 6
#       1 my_dict = {
#       2     'A' : 90,
#       3     'B' : 80,
#       4     'C' : 70
#       5 }
# ----> 6 print(my_dict['D'])
#
# KeyError: 'D'

# %%
a = 10
b = '20'
print(a + b)

# or
s = 'shivam rathaur'
print(s.count(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[11], line 3
#       1 a = 10
#       2 b = '20'
# ----> 3 print(a + b)
#       5 # or
#       6 s = 'shivam rathaur'
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %% [markdown]
# * Another way to get type error

# %%
s = 'shivam rathaur'
print(s.count(a))
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[15], line 3
#       1 # or
#       2 s = 'shivam rathaur'
# ----> 3 print(s.count(a))
#
# TypeError: must be str, not int
