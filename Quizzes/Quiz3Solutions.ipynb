# %% [markdown]
# ##### MS1980 Quiz3 Solutions
# ###### © Shivam Rathaur 2024
# ----------

# %% [markdown]
# ![Screenshot 2024-10-12 153859.png](data:image/png;base64,...)

# %% [markdown]
# a) The line C = A * B will produce an error bcz A & B are not compatible for element-wise matrix multiplication.
#
# b) $Sol^n$:

# %%
# corrected code
import numpy as np
A = np.array([1,2,3,4])
B = np.array([5,6,7])
A = np.reshape(A,(4,1)) # or A = A[:, np.newaxis] -> a column vector
C = A * B
total_sum = np.sum(C)
print(total_sum)
# Out:
# 180

# %% [markdown]
# ![Screenshot 2024-10-12 153917.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-12 153932.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-12 153950.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-12 154005.png](data:image/png;base64,...)

# %%
# Q3 Soln
