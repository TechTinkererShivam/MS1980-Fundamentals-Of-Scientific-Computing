# %% [markdown]
# ##### MS1980 Practice Sheet IV Solutions
# ###### © Shivam Rathaur 2024
# ----------

# %% [markdown]
# ![Screenshot 2024-10-12 151748.png](data:image/png;base64,...)

# %%
# def my_rec_det(M):

# %% [markdown]
# ![Screenshot 2024-10-12 151759.png](data:image/png;base64,...)

# %%
import numpy as np

r = 1 # radius
n,N = 0, 50000
for i in range(N):
    c = np.random.rand(2) # coordinates(x,y)
    x,y = c[0], c[1]
    if((x**2 + y**2)<=r):
        n += 1

ans = (4*n)/N
print(ans)        

# Yes, the answer is close to PI
# Out:
# 3.14984

# %% [markdown]
# ![Screenshot 2024-10-12 151807.png](data:image/png;base64,...)

# %%
# Q3 Soln

# %% [markdown]
# ![Screenshot 2024-10-12 152132.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-12 152148.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-12 152205.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-12 152218.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-12 152549.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-12 152558.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2024-10-12 152607.png](data:image/png;base64,...)
