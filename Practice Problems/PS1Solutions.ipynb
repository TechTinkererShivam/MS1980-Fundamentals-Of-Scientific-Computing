# %% [markdown]
# ##### MS1980 Practice Sheet I Solutions
# ###### © Shivam Rathaur 2024
# ---

# %% [markdown]
# ![Screenshot 2024-10-12 145032.png](data:image/png;base64,...)

# %%
# Q1 to Q6 -> already solved

# %% [markdown]
# ![Screenshot 2024-10-12 145155.png](data:image/png;base64,...)

# %%
# Q7 Solution
tuple_a = ('One', 1)
print(tuple_a, type(tuple_a))
# Out:
# ('One', 1) <class 'tuple'>

# %% [markdown]
# ![Screenshot 2024-10-12 145309.png](data:image/png;base64,...)

# %%
# Q8 Solution
set_a = {2,3,2}
set_b = {1,2,3}
print(set_a.union(set_b), set_a | set_b) # union
print(set_a.intersection(set_b), set_a & set_b) # intersection
print(set_b.difference(set_a), set_a - set_b) # difference
# Out:
# {1, 2, 3} {1, 2, 3}
# {2, 3} {2, 3}
# {1} set()

# %% [markdown]
# ![Screenshot 2024-10-12 145356.png](data:image/png;base64,...)

# %%
# Q9 Solution
tuple_1 = (('a', 23),('b',37),('c',11), ('d',29))
print(tuple_1)

def custom_sort(tuple_1): # sort by the 2nd element of each tuple
    return tuple_1[1]

# code to sort the tuple of tuples by the second item
sorted_tuple_1 = tuple(sorted(tuple_1, key=custom_sort))
print(sorted_tuple_1)
# Out:
# (('a', 23), ('b', 37), ('c', 11), ('d', 29))
# (('c', 11), ('a', 23), ('d', 29), ('b', 37))

# %% [markdown]
# ![Screenshot 2024-10-12 145443.png](data:image/png;base64,...)

# %%
# 10 Solution
from copy import deepcopy
#create a tuple
t = ("Tutor", 'J', 23 , 56.67 , [23,12] , True)
print(t)
#make a copy of a tuple using deepcopy() function
tc = deepcopy(t)
tc[4].append(50)
print(tc)
print(t)
# Why was deepcopy() used?
# Ans: deepcopy() is used to ensure that changes made to tc do not affect c.
# Out:
# ('Tutor', 'J', 23, 56.67, [23, 12], True)
# ('Tutor', 'J', 23, 56.67, [23, 12, 50], True)
# ('Tutor', 'J', 23, 56.67, [23, 12], True)
